# %%
# Lista de Exercício 4

# %% [raw]
# title: Análise de Renda média do trabalho principal - áreas rurais
# author: "Ellen Gomes"
# date: "21 de junho de 2023"
# lang: pt
# format:
#   html:
#     code-tools: true
#     code-fold: true
#     default-image-extension: png
#     page-layout: full
# jupyter: python3

# %%
# !pip install ipeadatapy

import ipeadatapy as ip

# %%
help(ip.timeseries)
# Out:
# Help on function timeseries in module ipeadatapy.timeseries:
#
# timeseries(series, year=None, yearGreaterThan=None, yearSmallerThan=None, day=None, dayGreaterThan=None, daySmallerThan=None, month=None, monthGreaterThan=None, monthSmallerThan=None, code=None, date=None)
#     Returns the specified time series' data values. `series` must be a time series code
#     :param series: Time series code. For the available time series run list_series()
#     :type series: str
#     :param year: Year which the data set will be restricted to.
#     :type year: int, optional
#     :param yearGreaterThan: Year which the data set will be restricted to years strictly greater.
#     :type yearGreaterThan: int, optional
#     :param yearSmallerThan: Year which the data set will be restricted to years strictly smaller.
#     :type yearSmallerThan: int, optional
#     :param day: Day which the data set will be restricted to.
#     :type day: int, optional
# ...

# %%
ip.list_series('Renda')
# Out:
#                   CODE                                               NAME
# 7155      DISOC_RENDAP                  Renda média do trabalho principal
# 7156  DISOC_RENDAPMETR  Renda média do trabalho principal - áreas metr...
# 7157  DISOC_RENDAPNAOM  Renda média do trabalho principal - áreas não-...
# 7158  DISOC_RENDAPRURA   Renda média do trabalho principal - áreas rurais
# 7159  DISOC_RENDAPURBA  Renda média do trabalho principal - áreas urba...
# ...                ...                                                ...
# 8937        RendaTodos                  Renda média de todos os trabalhos
# 8938   RendaTodos_Metr  Renda média de todos os trabalhos - áreas metr...
# 8939   RendaTodos_NaoM  Renda média de todos os trabalhos - áreas não-...
# 8940   RendaTodos_Rura   Renda média de todos os trabalhos - áreas rurais
# 8941   RendaTodos_Urba  Renda média de todos os trabalhos - áreas urba...
#
# [130 rows x 2 columns]

# %%
ip.describe('DISOC_RENDAPRURA')
# Out:
#                  Renda média do trabalho principal - áreas rurais
# Name             Renda média do trabalho principal - áreas rurais
# Code                                             DISOC_RENDAPRURA
# Big Theme                                          Macroeconômico
# Theme code                                                     12
# Source                   Instituto de Pesquisa Econômica Aplicada
# Source acronym                                               IPEA
# Comment         Média, por pessoa ocupada, dos rendimentos men...
# Last update                             2016-01-08T12:12:23-02:00
# Frequency                                                   Anual
# Measure                                           R$ Outubro 2014
# Unit                                                         None
# Status                                                          I

# %%
ip.timeseries('DISOC_RENDAPRURA')
# Out:
#                         CODE                   RAW DATE  DAY  MONTH  YEAR  \
# DATE
# 1992-01-01  DISOC_RENDAPRURA  1992-01-01T00:00:00-02:00    1      1  1992
# 1993-01-01  DISOC_RENDAPRURA  1993-01-01T00:00:00-02:00    1      1  1993
# 1994-01-01  DISOC_RENDAPRURA  1994-01-01T00:00:00-02:00    1      1  1994
# 1995-01-01  DISOC_RENDAPRURA  1995-01-01T00:00:00-02:00    1      1  1995
# 1996-01-01  DISOC_RENDAPRURA  1996-01-01T00:00:00-02:00    1      1  1996
# 1997-01-01  DISOC_RENDAPRURA  1997-01-01T00:00:00-02:00    1      1  1997
# 1998-01-01  DISOC_RENDAPRURA  1998-01-01T00:00:00-02:00    1      1  1998
# 1999-01-01  DISOC_RENDAPRURA  1999-01-01T00:00:00-02:00    1      1  1999
# 2000-01-01  DISOC_RENDAPRURA  2000-01-01T00:00:00-02:00    1      1  2000
# 2001-01-01  DISOC_RENDAPRURA  2001-01-01T00:00:00-02:00    1      1  2001
# 2002-01-01  DISOC_RENDAPRURA  2002-01-01T00:00:00-02:00    1      1  2002
# 2003-01-01  DISOC_RENDAPRURA  2003-01-01T00:00:00-02:00    1      1  2003
# ...

# %%
ip.timeseries('DISOC_RENDAPRURA').plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
def DISOC_RENDAPRURA(value2012, value2011): 
    percurso = value2012 - value2011 
    print(percurso) 

print ("Diferença entre o ano de 2011 e 2012")
DISOC_RENDAPRURA(705.705423, 640.337640)
# Out:
# Diferença entre o ano de 2011 e 2012
# 65.36778300000003

# %%
410.050058==2005
458.533931==2006

if 2005 > 2006:
    print("A sentença é verdadeira!") 
else: 
    print("A sentença é falsa!")
# Out:
# A sentença é falsa!

# %%
for contador in range(1992,2015):
    print(contador)
# Out:
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014

# %%
#função filter()

def verificaPar(num):
    if num % 2 == 0:
        print("Verdadeiro")
    else:
        print("Falso")

verificaPar(1041.308696)
# Out:
# Falso
